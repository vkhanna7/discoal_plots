# %%
# %run discoal_default.py -"discoal_default"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_c_0.2.txt"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_c_0.5.txt"
# Out:
# 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/discoal/Comparison plots /discoal_default.py:101
#      99         for k in range(len(win)-1):
#     100             if(pos[j][i]>=win[k] and pos[j][i]<win[k+1]):
# --> 101                 win_het[j][k]+=total_het[j][i]/((10**6)/11)
#     102 #print(win_het)
#     103 x=[i for i in range(1,12)]
#
# IndexError: list index out of range

# %%
# %run discoal_default.py -txt "discoal_a_2000.txt"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_a_2000_c_0.5.txt"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_a_2000_c_0.2.txt"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_a_1000.txt"
# Out:
# 20

# %%
# %run discoal_default.py -txt "discoal_ws_100.txt"
# Out:
# 20
