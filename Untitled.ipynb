# %%
# %run msprime_default.py
# %run discoal_default.py
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -c 0.2
# %run discoal_default.py -txt "discoal_c_0.2.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -a 1000
# %run discoal_default.py -txt "discoal_a_1000.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -a 2000
# %run discoal_default.py -txt "discoal_a_2000.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -a 2000 -c 0.2
# %run discoal_default.py -txt "discoal_a_2000_c_0.2.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -a 2000  -c 0.5
# %run discoal_default.py -txt "discoal_a_2000_c_0.5.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -ws 100
# %run discoal_default.py -txt "discoal_ws_100.txt"
# %run plots.py
# Out:
# 20
