# %%
# %run msprime_default.py -reps 1000
# %run discoal_default.py -txt "discoal_default_rep_1000.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -reps 1000 -c 0.2
# %run discoal_default.py -txt "discoal_rep_1000_c_0.2.txt"
# %run plots.py
# Out:
# 20

# %%
# %run msprime_default.py -reps 1000 -c 0.5
# %run discoal_default.py -txt "discoal_rep_1000_c_0.5.txt"
# %run plots.py
# Out:
# 20
